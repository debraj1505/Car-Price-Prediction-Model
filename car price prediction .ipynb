# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Data Understanding and Exploration

# %%
df  = pd.read_csv("CarPricePrediction.csv")
df
# Out:
#                                      name  year  selling_price  km_driven  \
# 0                           Maruti 800 AC  2007          60000      70000
# 1                Maruti Wagon R LXI Minor  2007         135000      50000
# 2                    Hyundai Verna 1.6 SX  2012         600000     100000
# 3                  Datsun RediGO T Option  2017         250000      46000
# 4                   Honda Amaze VX i-DTEC  2014         450000     141000
# ...                                   ...   ...            ...        ...
# 4335  Hyundai i20 Magna 1.4 CRDi (Diesel)  2014         409999      80000
# 4336           Hyundai i20 Magna 1.4 CRDi  2014         409999      80000
# 4337                  Maruti 800 AC BSIII  2009         110000      83000
# 4338     Hyundai Creta 1.6 CRDi SX Option  2016         865000      90000
# 4339                     Renault KWID RXT  2016         225000      40000
#
#         fuel seller_type transmission         owner
# ...

# %%
df.head()
# Out:
#                        name  year  selling_price  km_driven    fuel  \
# 0             Maruti 800 AC  2007          60000      70000  Petrol
# 1  Maruti Wagon R LXI Minor  2007         135000      50000  Petrol
# 2      Hyundai Verna 1.6 SX  2012         600000     100000  Diesel
# 3    Datsun RediGO T Option  2017         250000      46000  Petrol
# 4     Honda Amaze VX i-DTEC  2014         450000     141000  Diesel
#
#   seller_type transmission         owner
# 0  Individual       Manual   First Owner
# 1  Individual       Manual   First Owner
# 2  Individual       Manual   First Owner
# 3  Individual       Manual   First Owner
# 4  Individual       Manual  Second Owner

# %%
df.tail()
# Out:
#                                      name  year  selling_price  km_driven  \
# 4335  Hyundai i20 Magna 1.4 CRDi (Diesel)  2014         409999      80000
# 4336           Hyundai i20 Magna 1.4 CRDi  2014         409999      80000
# 4337                  Maruti 800 AC BSIII  2009         110000      83000
# 4338     Hyundai Creta 1.6 CRDi SX Option  2016         865000      90000
# 4339                     Renault KWID RXT  2016         225000      40000
#
#         fuel seller_type transmission         owner
# 4335  Diesel  Individual       Manual  Second Owner
# 4336  Diesel  Individual       Manual  Second Owner
# 4337  Petrol  Individual       Manual  Second Owner
# 4338  Diesel  Individual       Manual   First Owner
# 4339  Petrol  Individual       Manual   First Owner

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4340 entries, 0 to 4339
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           4340 non-null   object
#  1   year           4340 non-null   int64
#  2   selling_price  4340 non-null   int64
#  3   km_driven      4340 non-null   int64
#  4   fuel           4340 non-null   object
#  5   seller_type    4340 non-null   object
#  6   transmission   4340 non-null   object
#  7   owner          4340 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 271.4+ KB

# %%
df.describe()
# Out:
#               year  selling_price      km_driven
# count  4340.000000   4.340000e+03    4340.000000
# mean   2013.090783   5.041273e+05   66215.777419
# std       4.215344   5.785487e+05   46644.102194
# min    1992.000000   2.000000e+04       1.000000
# 25%    2011.000000   2.087498e+05   35000.000000
# 50%    2014.000000   3.500000e+05   60000.000000
# 75%    2016.000000   6.000000e+05   90000.000000
# max    2020.000000   8.900000e+06  806599.000000

# %%
df.isnull().sum()
# Out:
# name             0
# year             0
# selling_price    0
# km_driven        0
# fuel             0
# seller_type      0
# transmission     0
# owner            0
# dtype: int64

# %%
num_col = ['year', 'selling_price', 'km_driven']
correlation_matrix = df[num_col].corr()
print(correlation_matrix)
# Out:
#                    year  selling_price  km_driven
# year           1.000000       0.413922  -0.419688
# selling_price  0.413922       1.000000  -0.192289
# km_driven     -0.419688      -0.192289   1.000000

# %%
# plotting the heatmap for correlation matrix
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix on Numerical Features')
plt.show()

# %% [markdown]
# 2. Exploratory Data Analysis (EDA)

# %%
plt.figure(figsize = (10,2))
plt.subplot(1,2,1)
sns.scatterplot(x='year', y='selling_price', data=df)
plt.title("selling_price vs year")
plt.xlabel("year")
plt.ylabel("selling_price")
plt.show()


plt.figure(figsize = (10,2))
plt.subplot(1,2,2)
sns.scatterplot(x='km_driven', y='selling_price', data=df)
plt.title("selling_price vs km_driven")
plt.xlabel("km_driven")
plt.ylabel("selling_price")
plt.show()

# %%
categorical_col = ['fuel', 'seller_type', 'transmission', 'owner']

plt.figure(figsize=(15,10))
for i, col in enumerate(categorical_col):
    plt.subplot(2, 2, i + 1)
    sns.boxplot(x=col, y='selling_price', data=df)
    plt.title(f'Selling Price vs. {col}')
    plt.xlabel(col)
    plt.ylabel('Selling Price')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(15, 5))

plt.subplot(1, 3, 1)
sns.histplot(df['year'], kde=True)
plt.title('Distribution of Year')
plt.xlabel('Year')
plt.ylabel('Frequency')

plt.subplot(1, 3, 2)
sns.histplot(df['selling_price'], kde=True)
plt.title('Distribution of selling price')
plt.xlabel('selling price')
plt.ylabel('Frequency')

plt.subplot(1, 3, 3)
sns.histplot(df['km_driven'], kde=True)
plt.title('Distribution of km_driven')
plt.xlabel('km_driven')
plt.ylabel('Frequency')
# Out:
# C:\Users\DEBRAJ MONDAL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\DEBRAJ MONDAL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\DEBRAJ MONDAL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Text(0, 0.5, 'Frequency')

# %%
plt.figure(figsize=(15, 5))

plt.subplot(1, 3, 1)
sns.boxplot(y=df['year'])
plt.title('Box Plot of Year')
plt.ylabel('Year')

plt.subplot(1, 3, 2)
sns.boxplot(y=df['selling_price'])
plt.title('Box Plot of selling price')
plt.ylabel('selling_price')

plt.subplot(1, 3, 3)
sns.boxplot(y=df['km_driven'])
plt.title('Box Plot of km_driven')
plt.ylabel('km_driven')
# Out:
# Text(0, 0.5, 'km_driven')

# %%
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %% [markdown]
# Data Preprocessing

# %%
# outler removal for selling price
df_processed = df.drop('name', axis=1)


Q1_price = df_processed['selling_price'].quantile(0.25)
Q3_price = df_processed['selling_price'].quantile(0.75)
IQR_price = Q3_price - Q1_price
lower_bound_price = Q1_price - 1.5 * IQR_price
upper_bound_price = Q3_price + 1.5 * IQR_price
df_processed = df_processed[(df_processed['selling_price'] >= lower_bound_price) & (df_processed['selling_price'] <= upper_bound_price)]

# %%
# outlier removal for km driven
Q1_km = df_processed['km_driven'].quantile(0.25)
Q3_km = df_processed['km_driven'].quantile(0.75)
IQR_km = Q3_km - Q1_km
lower_bound_km = Q1_km - 1.5 * IQR_km
upper_bound_km = Q3_km + 1.5 * IQR_km
df_processed = df_processed[(df_processed['km_driven'] >= lower_bound_km) & (df_processed['km_driven'] <= upper_bound_km)]

# %%
print(f"Shape of data after outlier removal: {df_processed.shape}")
# Out:
# Shape of data after outlier removal: (3962, 7)

# %%
X = df.drop('selling_price', axis=1)
y = df['selling_price']

# %%
categorical_cols = X.select_dtypes(include='object').columns
numerical_cols = X.select_dtypes(include=['int64', 'float64']).columns

# %%
encoder = OneHotEncoder(handle_unknown='ignore', sparse_output=False)
encoded_features = encoder.fit_transform(X[categorical_cols])
encoded_feature_names = encoder.get_feature_names_out(categorical_cols)
encoded_df = pd.DataFrame(encoded_features, columns=encoded_feature_names, index=X.index)

# %%
X_processed = pd.concat([X[numerical_cols], encoded_df], axis=1)

# %%
scaler = StandardScaler()
X_processed[numerical_cols] = scaler.fit_transform(X_processed[numerical_cols])

# %%
X_train, X_test, y_train, y_test = train_test_split(X_processed, y, test_size=0.2, random_state=42)

# %%
print(X_train.head())
# Out:
#           year  km_driven  name_Ambassador CLASSIC 1500 DSL AC  \
# 227   0.927485  -0.990931                                  0.0
# 964   1.164741  -0.347689                                  0.0
# 2045 -0.021539  -0.883724                                  0.0
# 1025 -0.496051   0.081139                                  0.0
# 4242  0.927485   0.124022                                  0.0
#
#       name_Ambassador Classic 2000 Dsz  \
# 227                                0.0
# 964                                0.0
# 2045                               0.0
# 1025                               0.0
# 4242                               0.0
#
#       name_Ambassador Grand 1800 ISZ MPFI PW CL  name_Audi A4 1.8 TFSI  \
# 227                                         0.0                    0.0
# 964                                         0.0                    0.0
# 2045                                        0.0                    0.0
# ...

# %% [markdown]
# Model Development

# %%
linear_reg_model = LinearRegression()
linear_reg_model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = linear_reg_model.predict(X_test)
print(y_pred[:10])
# Out:
# [ 159714.26746097  464661.39590378   93765.20652599  493510.7172469
#  1414422.73900493  247295.4308594   560953.66585167  165255.22816557
#   500697.40006116  293053.26055197]

# %%
print(y_test[:10].values)
# Out:
# [165000 250000 120000 450000 730000 155000 530000  92800 284000 260000]

# %% [markdown]
# Model Evaluation

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2_rf= r2_score(y_test, y_pred)

print(f"Mean Absolute Error (MAE): {mae:.2f}")
print(f"Mean Squared Error (MSE): {mse:.2f}")
print(f"Root Mean Squared Error (RMSE): {rmse:.2f}")
print(f"R-squared (R²): {r2_rf:.2f}")
# Out:
# Mean Absolute Error (MAE): 120931.93
# Mean Squared Error (MSE): 116189180899.29
# Root Mean Squared Error (RMSE): 340865.34
# R-squared (R²): 0.62

# %% [markdown]
# Model Interpretation

# %%
# Most Impactful Features:
# For the Linear Regression model, the scaled coefficients indicate the impact of each feature.

# year: A positive coefficient (approximately $136,416 after scaling) suggests that newer cars command higher prices.

# km_driven: A negative coefficient (approximately −49,808 after scaling) indicates that higher mileage generally leads to lower selling prices.

# Categorical Features: While exact interpretation of individual one-hot encoded categories requires comparing
# them against the dropped baseline category, features like fuel type (e.g., Diesel vs. Petrol), transmission (Automatic vs. Manual),
# seller_type, and owner status are clearly influential in determining car prices, as observed in EDA.

# %%
# Model Strengths:

# Simplicity and Speed: Linear Regression is quick to train and easy to understand.

# Interpretability: The coefficients provide a direct insight into how each feature linearly affects the car price (with careful interpretation for encoded variables).

# Baseline Performance: Serves as a solid starting point for a prediction task.

# Model Limitations:

# Assumes Linearity: The model assumes a linear relationship, which might not fully capture complex, non-linear patterns in car pricing data.

# Sensitivity to Outliers: Although outliers were removed, extreme values can still influence the model if not perfectly handled.

# Limited Explanatory Power: An R 
# 2
#   of 0.54 suggests that almost half of the variance in car prices remains unexplained by the current features and model.

# %%
# Underfitting or Overfitting Issues:
# The R2 score of 0.54 on the test set indicates that the model is still underfitting to some extent.
# It suggests that the model, despite improvements, is too simple to fully capture the complexities and underlying patterns of car price determination.
# There's significant room for improvement by potentially exploring more sophisticated models or deriving more complex features.
# There's no strong evidence of overfitting (where the model performs very well on training data but poorly on test data),
# as the overall performance is moderate on the test set.
